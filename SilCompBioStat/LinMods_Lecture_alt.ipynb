# %% [markdown]
# What is a linear model?
# =======================
#
# \[t\]
#
# ### A combination of four components
#
# (0 mm, 0mm) rectangle (118 mm, 30mm);
#
# \[every node/.style=<span>text height=3mm, text depth=1mm, on chain,
# inner sep=0.5mm</span>, gr/.style=<span>teal</span>,
# rd/.style=<span>red</span>, bl/.style=<span>blue</span>,
# gy/.style=<span>gray</span>, start chain, node distance=0mm\]
#
# \(w) at (12mm, 19mm) <span>$w$</span>; (eq) <span>$=$</span>; (b1)
# <span>$\beta_1$</span>; (p) <span>$+$</span>; (b2)
# <span>$\beta_2$</span>; (h) <span>$h$</span>; (p) <span>$+$</span>; (b3)
# <span>$\beta_3$</span>; (e) <span>$e$</span>; (p) <span>$+$</span>; (b4)
# <span>$\beta_4$</span>; (g) <span>$g_m$</span>; (p) <span>$+$</span>;
# (b5) <span>$\beta_5$</span>; (d) <span>$d$</span>; (p) <span>$+$</span>;
# (b6) <span>$\beta_6$</span>; (cS) <span>$c_s$</span>; (p)
# <span>$+$</span>; (b7) <span>$\beta_7$</span>; (cA) <span>$c_a$</span>;
# (p) <span>$+$</span>; (eps) <span>$\varepsilon$</span>;
#
# \[every node/.style=<span>rounded corners, draw, minimum
# height=6mm</span>, every path/.style=<span>latex-, draw=red,
# thick</span>\]
#
# (exp) \[inner sep=0pt, yshift=1cm, fit=<span>(e) (cS)</span>,
# label=center:Explanatory variables, fill=blue!10, draw=blue\] ; (coef)
# \[inner sep=0pt, yshift=-1cm, fit=<span>(b2) (b6)</span>,
# label=center:Coefficients, fill=red!10, draw=red\] ; (resp) \[above =
# 4mm of w, fill=teal!10, draw=teal\] <span>Response variable</span>;
# (resid) \[below = 4.5mm of eps, fill=gray!10, draw=gray\]
# <span>Residuals</span>;
#
# iin <span>e, d, g, cS</span> (i.north) – (i.north |- exp.south);
# (cA.north) |- (exp.east); (h.north) |- (exp.west); iin <span>b2, b3, b4,
# b5, b6</span> (i.south) – (i.south |- coef.north); (b7.south) |-
# (coef.east); (b1.south) |- (coef.west); (w.north) – (resp.south);
# (eps.south) – (resid.north);
#
# -   A ($w$)
#
# -   A set of ($h,e,g,d,c$)
#
# -   A set of ($\beta_1$ – $\beta_7$)
#
# -   A set of ($\varepsilon$)
#
# \[t\]
#
# ### Different types of variables
#
# (0 mm, 0mm) rectangle (118 mm, 30mm);
#
# \[every node/.style=<span>text height=3mm, text depth=1mm, on chain,
# inner sep=0.5mm</span>, gr/.style=<span>teal</span>,
# rd/.style=<span>red</span>, bl/.style=<span>blue</span>,
# gy/.style=<span>gray</span>, start chain, node distance=0mm\]
#
# \(w) at (12mm, 19mm) <span>$w$</span>; (eq) <span>$=$</span>; (b1)
# <span>$\beta_1$</span>; (p) <span>$+$</span>; (b2)
# <span>$\beta_2$</span>; (h) <span>$h$</span>; (p) <span>$+$</span>; (b3)
# <span>$\beta_3$</span>; (e) <span>$e$</span>; (p) <span>$+$</span>; (b4)
# <span>$\beta_4$</span>; (g) <span>$g_m$</span>; (p) <span>$+$</span>;
# (b5) <span>$\beta_5$</span>; (d) <span>$d$</span>; (p) <span>$+$</span>;
# (b6) <span>$\beta_6$</span>; (cS) <span>$c_s$</span>; (p)
# <span>$+$</span>; (b7) <span>$\beta_7$</span>; (cA) <span>$c_a$</span>;
# (p) <span>$+$</span>; (eps) <span>$\varepsilon$</span>;
#
# \[every node/.style=<span>rounded corners, draw, minimum
# height=6mm</span>, every path/.style=<span>latex-, draw=red,
# thick</span>\]
#
# (cont) \[inner sep=0pt, yshift=1cm, fit=<span>(w) (d)</span>,
# label=center:Continuous variables, fill=blue!10, draw=blue\] ; (cat)
# \[inner sep=0pt, yshift=-1cm, fit=<span>(g) (cA)</span>,
# label=center:Categorical variables, fill=red!10, draw=red\] ;
#
# iin <span>w, h, e, d</span> (i.north) – (i.north |- exp.south); iin
# <span>g, cA, cS</span> (i.south) – (i.south |- coef.north);
#
# -   The response variable is always .
#
# -   The explanatory variables can be a mix of:

# %%
-   variables: height, exercise and distance.

-   variables: gender and console ownership.

# %% [markdown]
# -   variables or <span>*factors*</span> have a number of
#     <span>*levels*</span>:

# %%
-   Gender has two levels (Male / Female)

-   Console has three levels (None / Sofa-based / Active)

# %% [markdown]
# \[t\]
#
# ### Terms and coefficients
#
# (0 mm, 0mm) rectangle (118 mm, 30mm);
#
# \[every node/.style=<span>text height=3mm, text depth=1mm, on chain,
# inner sep=0.5mm</span>, gr/.style=<span>teal</span>,
# rd/.style=<span>red</span>, bl/.style=<span>blue</span>,
# gy/.style=<span>gray</span>, start chain, node distance=0mm\]
#
# \(w) at (12mm, 19mm) <span>$w$</span>; (eq) <span>$=$</span>; (b1)
# <span>$\beta_1$</span>; (p) <span>$+$</span>; (b2)
# <span>$\beta_2$</span>; (h) <span>$h$</span>; (p) <span>$+$</span>; (b3)
# <span>$\beta_3$</span>; (e) <span>$e$</span>; (p) <span>$+$</span>; (b4)
# <span>$\beta_4$</span>; (g) <span>$g_m$</span>; (p) <span>$+$</span>;
# (b5) <span>$\beta_5$</span>; (d) <span>$d$</span>; (p) <span>$+$</span>;
# (b6) <span>$\beta_6$</span>; (cS) <span>$c_s$</span>; (p)
# <span>$+$</span>; (b7) <span>$\beta_7$</span>; (cA) <span>$c_a$</span>;
# (p) <span>$+$</span>; (eps) <span>$\varepsilon$</span>;
#
# \[every node/.style=<span>rounded corners, draw, minimum
# height=6mm</span>, every path/.style=<span>latex-, draw=red,
# thick</span>\]
#
# (height) \[below=0.5cm of h, fill=blue!10, draw=blue, xshift=-3mm\]
# <span>Height</span>; (h.south) – (h.south |- height.north);
#
# (exercise) \[below=0.5cm of e, fill=blue!10, draw=blue, xshift=4mm\]
# <span>Exercise</span>; (e.south) – (e.south |- exercise.north);
#
# (distance) \[below=0.5cm of d, fill=blue!10, draw=blue\]
# <span>Distance</span>; (d.south) – (d.south |- distance.north);
#
# (gender) \[above=0.5cm of g, fill=red!10, draw=red\]
# <span>Gender</span>; (g.north) – (g.north |- gender.south);
#
# (console) \[inner sep=0pt, yshift=1.1cm, fit=<span>(cA) (cS)</span>,
# label=center:Console, fill=red!10, draw=red\] ; iin <span>cA, cS</span>
# (i.north) – (i.north |- console.south);
#
# -   Each explanatory variable is a <span>*term*</span> in the model
#
# -   Each term has at least one coefficient
#
# -   terms always have one coefficient
#
# -   have $N - 1$ coefficients, where $N$ is the number of levels
#
# \[t\]
#
# ### Wait! Why $N-1$? What is $\beta_1$?
#
# \[every node/.style=<span>text height=3mm, text depth=1mm, on chain,
# inner sep=0.5mm</span>, gr/.style=<span>teal</span>,
# rd/.style=<span>red</span>, bl/.style=<span>blue</span>,
# gy/.style=<span>gray</span>, pr/.style=<span>draw, rounded corners=2mm,
# gray</span>, start chain, node distance=0mm\]
#
# (0 mm, 0mm) rectangle (118 mm, 21mm); (w) at (12mm, 10mm)
# <span>$w$</span>; (eq) <span>$=$</span>; (b1) <span>$\beta_1$</span>;
# (p) <span>$+$</span>; (b2) <span>$\beta_2$</span>; (h) <span>$h$</span>;
# (p) <span>$+$</span>; (b3) <span>$\beta_3$</span>; (e) <span>$e$</span>;
# (p) <span>$+$</span>; (b4) <span>$\beta_4$</span>; (g)
# <span>$g_m$</span>; (p) <span>$+$</span>; (b5) <span>$\beta_5$</span>;
# (d) <span>$d$</span>; (p) <span>$+$</span>; (b6) <span>$\beta_6$</span>;
# (cS) <span>$c_s$</span>; (p) <span>$+$</span>; (b7)
# <span>$\beta_7$</span>; (cA) <span>$c_a$</span>; (p) <span>$+$</span>;
# (eps) <span>$\varepsilon$</span>;
#
# ; ; ; ; ; ; ;
#
# -   Two ways of thinking about $\beta_1$:

# %%
-   Continuous variables: the $y$ <span>*intercept*</span>

-   Factors: the baseline or <span>*reference*</span> value

# %% [markdown]
# -   This baseline is the value for the <span>*first levels*</span> of
#     each factor
#
# -   All response values start at this baseline
#
# -   All the other coefficients measure <span>*differences*</span> from
#     $\beta_1$:

# %%
-   along a continuous slope

-   as an offset to a different level

# %% [markdown]
# \[t\]
#
# ### Linear models are just a sum
#
# \[every node/.style=<span>text height=3mm, text depth=1mm, on chain,
# inner sep=0.5mm</span>, cross/.style=<span>path picture=<span> (path
# picture bounding box.center) +(0, 1.4mm) – +(0, -1.4mm) (path picture
# bounding box.center) +(1.4mm, 0mm) – +(-1.4mm,0) ;</span></span>,
# gr/.style=<span>teal</span>, rd/.style=<span>cross, red</span>,
# bl/.style=<span>blue</span>, gy/.style=<span>gray</span>,
# pr/.style=<span>draw, rounded corners=2mm, gray</span>, start chain,
# node distance=0mm\]
#
# (0 mm, 0mm) rectangle (118 mm, 21mm); (w) at (12mm, 10mm)
# <span>$w$</span>; (eq) <span>$=$</span>; (b1) <span>$\beta_1$</span>;
# (p) <span>$+$</span>; (b2) <span>$\beta_2$</span>; (h) <span>$h$</span>;
# (p) <span>$+$</span>; (b3) <span>$\beta_3$</span>; (e) <span>$e$</span>;
# (p) <span>$+$</span>; (b4) <span>$\beta_4$</span>; (g)
# <span>$g_m$</span>; (p) <span>$+$</span>; (b5) <span>$\beta_5$</span>;
# (d) <span>$d$</span>; (p) <span>$+$</span>; (b6) <span>$\beta_6$</span>;
# (cS) <span>$c_s$</span>; (p) <span>$+$</span>; (b7)
# <span>$\beta_7$</span>; (cA) <span>$c_a$</span>; (p) <span>$+$</span>;
# (eps) <span>$\varepsilon$</span>;
#
# -   Find the baseline value for women with no games console ($\beta_1$)
#
# -   The model tells us how much to add to this…

# %%
-   for a height of 1.82 metres?

-   for doing 150 minutes of exercise a week?

-   for being male?

-   for living 2416 metres from a Greggs?

-   for owning an Xbox?

# %% [markdown]
# How do we deal with variation?
# ==============================
#
# Is a linear model appropriate?
# ==============================
#
# \[T\]
#
# ### ‘The model is linear’
#
# ![image](Linear.pdf){width="\textwidth"}
#
# -   These are <span>*all*</span> good linear models.
#
# -   Linear models can include curved relationships (e.g. polynomials)
#
# -   The data can be modelled as a <span>*sum*</span> of components
#
# -   A <span>*linear combination*</span> of variables and coefficients
#
# \[T\]
#
# ### ‘The model has constant normal variance’
#
# \[T\]
#
# ![image](ResidDemo.pdf){height="72mm"}
#
# -   The data has a similar spread around any predicted point in the
#     model
#
# -   The residuals are normal
#
# -   Points <span>*should*</span> be spaced equally in the area under the
#     curve
#
# -   Expect mostly small but a few larger residuals
#
# \[T\]
#
# ### ‘The model has constant normal variance’
#
# ![image](ConstantVarianceMods.pdf){width="\textwidth"}
#
# -   Three good models

# %%
-   Is the spread the same for all fitted values?

-   Do the residuals match the normal expectation?

# %% [markdown]
# \[T\]
#
# ### ‘The model has constant normal variance’
#
# ![image](FitResid.pdf){width="95.00000%"}
#
# ![image](QQNorm.pdf){width="95.00000%"}
#
# \[T\]
#
# ### ‘The model has constant normal variance’
#
# ![image](NonConstantVarianceMods.pdf){width="\textwidth"}
#
# -   Three bad models

# %%
-   Is the spread the same for all fitted values?

-   Do the residuals match the normal expectation?

# %% [markdown]
# \[T\]
#
# ### ‘The model has constant normal variance’
#
# ![image](BadFitResid.pdf){width="95.00000%"}
#
# ![image](BadQQNorm.pdf){width="95.00000%"}
#
# Is a linear model explanatory?
# ==============================
#
# \[T\]
#
# ### Null and over-specified models - two endpoints
#
# \[T\]
#
# ![image](NullSaturated.pdf){height="72mm"}
#
# -   The null model ($H_0$)
#
# -   Nothing is going on
#
# -   Biggest possible residuals
#
# -   Residual sum of squares (RSS) is as big as it can be
#
# -   The saturated model
#
# -   One coefficient per data point
#
# -   RSS is zero - all the sums of squares are now explained (ESS)
#
# \[T\]
#
# ### More interesting models
#
# ![image](Intermediate.pdf){height="0.5\textheight"}
#
# -   Added a term with three levels
#
# -   Some but not all of the residual sums of squares are explained
#
# -   Is this enough to be interesting?
#
# \[T\]
#
# ### The F statistic
#
# \[every node/.style=<span> text depth=1mm, inner sep=2mm,font=</span>,
# node distance=0mm\]
#
# (stat) <span>F</span>; (eq1) \[right= of stat\] <span>=</span>;
#
# (ratio1) \[right=of eq1,ampersand replacement=&\] <span> (ESS)
# <span>ESS</span>; (div1) \[right=of ESS\] <span>/</span>; (Nc) \[right=
# of div1\]<span>$N_c$</span> ;\
# (RSS) <span>RSS</span>; (div2) \[right=of RSS\]<span>/</span>; (Nr)
# \[right= of div2\]<span>$N_r$</span> ;\
# </span>;
#
# (ESS.south west) – (Nc.south east); (eq2) \[right= of ratio1\]
# <span>=</span>;
#
# (ratio2)\[right=of eq2,ampersand replacement=&\] <span> (ESSn)
# <span>9.92</span>; (div3) \[right=of ESSn\] <span>/</span>; (Ncn)
# \[right= of div3\]<span>$2$</span> ;\
# (RSSn) <span>6.59</span>; (div4) \[right=of RSSn\]<span>/</span>; (Nrn)
# \[right= of div4\]<span>$6$</span> ;\
# </span>;
#
# (ESSn.south west) – (Ncn.south east);
#
# (eq3) \[right= of ratio2\] <span>=</span>; (res) \[right= of eq3\]
# <span>4.52</span>;
#
# \[every node/.style=<span>fill=blue!10, draw=blue, font=, rounded
# corners, align=center</span>, every path/.style=<span>latex-, thick,
# draw=blue</span>\] (ESSGood) \[above=of ESS, yshift=8mm, xshift=-4mm\]
# <span>Large ESS\
# is good</span>; (RSSGood) \[below=of RSS, yshift=-8mm, xshift=-4mm\]
# <span>Small RSS\
# is good</span>; (NcGood) \[above=of Nc, yshift=8mm, xshift=8mm,
# anchor=south west\] <span>Fewer coefficients\
# is better</span>; (NrGood) \[below=of Nr, yshift=-8mm, xshift=8mm,
# anchor=north west\] <span>Residual degrees of freedom</span>;
#
# (ESS.north) – (ESS.north |- ESSGood.south); (RSS.south) – (RSS.south |-
# RSSGood.north); (Nc.north) |- (NcGood.west); (Nr.south) |-
# (NrGood.west);
#
# \[T\]
#
# ### $F$ values by chance
#
# ![image](F_extremes.pdf){width="\textwidth"}
#
# -   What is the distribution of $F$ if nothing is going on?
#
# -   Simulate 10,000 datasets where nothing is going on ($H_0$ is true)
#
# -   Calculate $F$ for each random dataset under $H_1$
#
# -   Mostly $H_1$ has a low $F$ - but sometimes it is high by chance
#
# \[T\]
#
# ### Distribution of $F$
#
# -   In our possibly interesting model, $F=4.52$
#
# -   &lt;2&gt; 95% of the random data sets have $F\le 5.5$
#
# -   &lt;2&gt; A model this good is found by chance 1 in 16 times
#     ($p=0.063$)
#
# -   &lt;2&gt; Not quite interesting enough!
#
# \[T\]
#
# ### Are coefficients different from zero?
#
# \[every node/.style=<span> text depth=1mm, inner sep=2mm,font=</span>,
# node distance=0mm\]
#
# (stat) <span>t</span>; (eq1) \[right= of stat\] <span>=</span>;
#
# (ratio1) \[right=of eq1,ampersand replacement=&\] <span> (diff)
# <span>Effect size</span>;\
# (prec) <span>Precision</span>;\
# </span>; (diff.south west) – (diff.south east);
#
# (eq2) \[right= of ratio1\] <span>=</span>;
#
# (ratio2) \[right=of eq2,ampersand replacement=&\] <span> (val)
# <span>Coefficient value</span>;\
# (se) <span>Standard error</span>;\
# </span>; (val.south west) – (val.south east);
#
# \[every node/.style=<span>fill=blue!10, draw=blue, font=, rounded
# corners, align=center</span>, every path/.style=<span>latex-, thick,
# draw=blue</span>\] (esgood) \[above=of eq2, yshift=10mm \] <span>Large
# is good - bigger changes</span>; (precgood) \[below=of eq2,
# yshift=-10mm\] <span>Small is good - known more precisely</span>;
#
# (diff.north) – (diff.north |- esgood.south); (val.north) – (val.north |-
# esgood.south); (prec.south) – (prec.south |- precgood.north); (se.south)
# – (se.south |- precgood.north);
#
# -   The value of a coefficient in a model is an <span>*effect
#     size*</span>
#
# -   How much does changing this variable change the response?
#
# -   A <span>*standard error*</span> estimates how precisely we know the
#     value
#
# \[T\]
#
# ### Variation in effect size and precision
#
# ![image](T_examples.pdf){height="75mm"}
#
# \[T\]
#
# ### $t$ values by chance
#
# ![image](t_extremes.pdf){width="\textwidth"}
#
# -   What is the distribution of $t$ if nothing is going on?
#
# -   Simulate 10,000 datasets where nothing is going on ($H_0$ is true)
#
# -   Calculate $t$ for each random dataset under $H_1$
#
# -   Mostly $H_1$ has a $t$ near zero but can be positive or negative
#
# \[T\]
#
# ### Distribution of $t$
#
# -   95% of the random data sets have $t\le \pm 2.09$
#
# -   Only the two higher precision models are expected to occur less than
#     1 time in 20 by chance.
#
# \[T\]
#
# ### Summary
#
# -   Linear models predict a continuous response variable
#
# -   A sum based on the effect size of explanatory variables
#
# -   Estimate the model using least squares residuals
#
# -   Need to check if the model is appropriate
#
# -   Then check if the model is explanatory
#
# \[T\]
#
# ### What about Analysis of Variance (ANOVA)?
#
# ![image](ANOVA_null.pdf){width="\textwidth"}
#
# -   The null hypothesis ($H_0$): Nothing is going on
#
# -   The residuals have to get smaller as we include terms.
#
# -   How much shorter?
#
# \[T\]
#
# ### Examples: one continuous term
#
# ![image](ANOVA_mod.pdf){width="\textwidth"}
#
# -   An alternative model ($H_1$) using $x$
#
# -   Added one term ($x$) to the model to give ($H_1$)
#
# -   Do we reject $H_0$ and accept this new model?
#
# \[T\]
#
# ### Examples: adding a factor
#
# ![image](ANOVA_mod2.pdf){width="\textwidth"}
#
# -   Another model ($H_2$) using $x$ and a factor $f$ with three levels
#
# -   The sum of squares gets smaller again
#
# -   We’ve added one term ($f$) but two coefficients ($f_b$ and $f_c$)
#
# -   Is this even better than $H_1$?
#
# \[T\]
#
# ### Change in variance

# %%
Model A   Model B   Model C
  -------- ---------------- --------- --------- ---------
   $H_0 $   Unexplained SS   241.97    185.02    259.80
             Explained SS       0         0         0
   $H_1 $   Unexplained SS   241.97    173.21     62.95
             Explained SS     0.00      11.81    196.85
   $H_2 $   Unexplained SS   238.07    123.75     25.05
             Explained SS      3.9      61.27    234.75

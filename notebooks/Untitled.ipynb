# %% [markdown]
# <h1>Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Ubuntu-/-Linux" data-toc-modified-id="Ubuntu-/-Linux-1">Ubuntu / Linux</a></span><ul class="toc-item"><li><span><a href="#Python-2.7-on-Ubuntu-16.04" data-toc-modified-id="Python-2.7-on-Ubuntu-16.04-1.1">Python 2.7 on Ubuntu 16.04</a></span></li><li><span><a href="#Mac" data-toc-modified-id="Mac-1.2">Mac</a></span></li><li><span><a href="#Windows" data-toc-modified-id="Windows-1.3">Windows</a></span></li></ul></li><li><span><a href="#Ubuntu-/-Linux" data-toc-modified-id="Ubuntu-/-Linux-2">Ubuntu / Linux</a></span><ul class="toc-item"><li><span><a href="#Python-2.7-on-Ubuntu-16.04" data-toc-modified-id="Python-2.7-on-Ubuntu-16.04-2.1">Python 2.7 on Ubuntu 16.04</a></span></li><li><span><a href="#Mac" data-toc-modified-id="Mac-2.2">Mac</a></span></li><li><span><a href="#Windows" data-toc-modified-id="Windows-2.3">Windows</a></span></li></ul></li></ul></div>

# %% [raw]
# #### Python 2.7 on Ubuntu 16.04
#
# If this does not work for python 2.7 on Ubuntu 16.04, do this:
#
# ``` bash
# sudo apt-get update
#
# sudo apt-get -y install python2.7 python-pip python-dev
#
# python --version
#
# pip --version
#
# sudo apt-get -y install ipython ipython-notebook
#
# sudo -H pip install jupyter
#
# ```
#
# You will likely get an error like: "You are using pip version 8.1.1, however version 8.1.2 is available."
#
# ``` bash
#
# sudo -H pip install --upgrade pip
#
# sudo -H pip install jupyter
#
# ```
#
# #### Mac
#
# ``` bash
# pip3 install --upgrade pip
#
# pip3 install jupyter
# ```
# #### Windows
#
# Best option is to download and install Anaconda: https://www.continuum.io/downloads

# %% [markdown]
# ### Ubuntu / Linux
#
# As an existing Python user, you may wish to install Jupyter using Python’s package manager, pip, instead of Anaconda. Do the following:
#
# ``` bash
# sudo pip3 install --upgrade pip
#
# pip3 install jupyter
# ```
# If pip3 is not available, then first:
#
# ```bash
# sudo apt-get install python3-pip
# ```
#
# <div style="padding:6px;background-color:cornsilk;line-height:1.4;">
#  If you already have python 2.x and then installed python3, your pip will be pointing to pip3. you can verify that by typing pip --version which would be the same as pip3 --version
# </div>
#
# #### Python 2.7 on Ubuntu 16.04
#
# If this does not work for python 2.7 on Ubuntu 16.04, do this:
#
# ``` bash
# sudo apt-get update
#
# sudo apt-get -y install python2.7 python-pip python-dev
#
# python --version
#
# pip --version
#
# sudo apt-get -y install ipython ipython-notebook
#
# sudo -H pip install jupyter
#
# ```
#
# You will likely get an error like: "You are using pip version 8.1.1, however version 8.1.2 is available."
#
# ``` bash
#
# sudo -H pip install --upgrade pip
#
# sudo -H pip install jupyter
#
# ```
#
# #### Mac
#
# ``` bash
# pip3 install --upgrade pip
#
# pip3 install jupyter
# ```
# #### Windows
#
# Best option is to download and install Anaconda: https://www.continuum.io/downloads

# %% [markdown]
# ### Ubuntu / Linux
#
# As an existing Python user, you may wish to install Jupyter using Python’s package manager, pip, instead of Anaconda. Do the following:
#
# ``` bash
# sudo pip3 install --upgrade pip
#
# pip3 install jupyter
# ```
# If pip3 is not available, then first:
#
# ```bash
# sudo apt-get install python3-pip
# ```
#
# <div style="padding:6px;background-color:cornsilk;line-height:1.4;">
#  If you already have python 2.x and then installed python3, your pip will be pointing to pip3. you can verify that by typing pip --version which would be the same as pip3 --version
# </div>
#
# #### Python 2.7 on Ubuntu 16.04
#
# If this does not work for python 2.7 on Ubuntu 16.04, do this:
#
# ``` bash
# sudo apt-get update
#
# sudo apt-get -y install python2.7 python-pip python-dev
#
# python --version
#
# pip --version
#
# sudo apt-get -y install ipython ipython-notebook
#
# sudo -H pip install jupyter
#
# ```
#
# You will likely get an error like: "You are using pip version 8.1.1, however version 8.1.2 is available."
#
# ``` bash
#
# sudo -H pip install --upgrade pip
#
# sudo -H pip install jupyter
#
# ```
#
# #### Mac
#
# ``` bash
# pip3 install --upgrade pip
#
# pip3 install jupyter
# ```
# #### Windows
#
# Best option is to download and install Anaconda: https://www.continuum.io/downloads
